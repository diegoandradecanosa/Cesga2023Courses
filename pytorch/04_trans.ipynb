# %%
# !pip install torch torchvision transformers datasets

import torch
from transformers import BertTokenizer, BertForQuestionAnswering
from transformers import Trainer, TrainingArguments
from datasets import load_dataset

# Paso 1: Cargar el conjunto de datos SQuAD v1.0
dataset = load_dataset("squad_v1")

# Paso 2: Cargar el modelo BERT pre-entrenado y el tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForQuestionAnswering.from_pretrained(model_name)

# Paso 3: Preprocesamiento y tokenización de los datos
def prepare_data(examples):
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        padding="max_length",
        max_length=384,
    )
    tokenized_examples["start_positions"] = examples["answers"]["answer_start"]
    tokenized_examples["end_positions"] = [
        start + len(answer_text) - 1
        for start, answer_text in zip(
            examples["answers"]["answer_start"], examples["answers"]["text"]
        )
    ]
    return tokenized_examples

train_dataset = dataset["train"].map(prepare_data, batched=True)
dev_dataset = dataset["validation"].map(prepare_data, batched=True)

# Paso 4: Configurar los argumentos de entrenamiento
training_args = TrainingArguments(
    output_dir="./squad_qa",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    save_total_limit=2,
    learning_rate=2e-5,
    evaluation_strategy="epoch",
    disable_tqdm=False,
)

# Paso 5: Entrenar el modelo con el Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset,
)

trainer.train()

# Paso 6: Evaluar el modelo en el conjunto de desarrollo
eval_results = trainer.evaluate(eval_dataset=dev_dataset)
print(eval_results)
# Out:
# Requirement already satisfied: torch in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: torchvision in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (0.14.1)
# Requirement already satisfied: transformers in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (4.25.1)
# Requirement already satisfied: datasets in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (2.13.1)
# Requirement already satisfied: typing_extensions in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from torch) (4.1.1)
# Requirement already satisfied: numpy in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from torchvision) (1.24.1)
# Requirement already satisfied: requests in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from transformers) (0.11.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: filelock in /home/roberto.lopez/.local/lib/python3.9/site-packages (from transformers) (3.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /home/roberto.lopez/.local/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: xxhash in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (8.0.0)
# Requirement already satisfied: multiprocess in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: pandas in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from datasets) (2022.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/roberto.lopez/.local/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.6.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (5.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/roberto.lopez/.local/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/roberto.lopez/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 from datasets import load_dataset
#       8 # Paso 1: Cargar el conjunto de datos SQuAD v1.0
# ----> 9 dataset = load_dataset("squad_v1")
#      11 # Paso 2: Cargar el modelo BERT pre-entrenado y el tokenizer
#      12 model_name = 'bert-base-uncased'
#
# File ~/anaconda3/lib/python3.9/site-packages/datasets/load.py:1785, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    1780 verification_mode = VerificationMode(
#    1781     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1782 )
#    1784 # Create a dataset builder
# -> 1785 builder_instance = load_dataset_builder(
#    1786     path=path,
#    1787     name=name,
#    1788     data_dir=data_dir,
#    1789     data_files=data_files,
#    1790     cache_dir=cache_dir,
#    1791     features=features,
#    1792     download_config=download_config,
#    1793     download_mode=download_mode,
#    1794     revision=revision,
#    1795     use_auth_token=use_auth_token,
#    1796     storage_options=storage_options,
#    1797     **config_kwargs,
#    1798 )
#    1800 # Return iterable dataset in case of streaming
#    1801 if streaming:
#
# File ~/anaconda3/lib/python3.9/site-packages/datasets/load.py:1514, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, storage_options, **config_kwargs)
#    1512     download_config = download_config.copy() if download_config else DownloadConfig()
#    1513     download_config.use_auth_token = use_auth_token
# -> 1514 dataset_module = dataset_module_factory(
#    1515     path,
#    1516     revision=revision,
#    1517     download_config=download_config,
#    1518     download_mode=download_mode,
#    1519     data_dir=data_dir,
#    1520     data_files=data_files,
#    1521 )
#    1523 # Get dataset builder class from the processing script
#    1524 builder_cls = import_main_class(dataset_module.module_path)
#
# File ~/anaconda3/lib/python3.9/site-packages/datasets/load.py:1227, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1225                 raise e1 from None
#    1226             if isinstance(e1, FileNotFoundError):
# -> 1227                 raise FileNotFoundError(
#    1228                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1229                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1230                 ) from None
#    1231             raise e1 from None
#    1232 else:
#
# FileNotFoundError: Couldn't find a dataset script at /home/roberto.lopez/Documentos/Git/Cesga2023Courses/pytorch/squad_v1/squad_v1.py or any data file in the same directory. Couldn't find 'squad_v1' on the Hugging Face Hub either: FileNotFoundError: Dataset 'squad_v1' doesn't exist on the Hub
